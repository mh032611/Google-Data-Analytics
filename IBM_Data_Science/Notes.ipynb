# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Try again once you are ready
# Grade received 60%
# Latest Submission Grade 40%
# To pass 70% or higher
# 1.
# Question 1
# Which library is used for machine learning?
#
# 0 / 1 point
#
# Scikit-learn
#
#
# Pandas
#
#
# NumPy
#
#
# Matplotlib
#
# Incorrect
# Incorrect. Review the Libraries for Data Science video.
#
# 2.
# Question 2
# Which deep learning library in Python is used for experimentation?
#
# 1 / 1 point
#
# Seaborn
#
#
# NumPy
#
#
# PyTorch
#
#
# Pandas
#
# Correct
# Correct! PyTorch is used for experimentation, making it simple for researchers to test ideas.
#
# 3.
# Question 3
# Which API can be used with TensorFlow?
#
# 0 / 1 point
#
# Panda
#
#
# Julia
#
#
# C language
#
#
# Seaborn
#
# Incorrect
# Incorrect. Review the Application Programming Interfaces (APIs) video.
#
# 4.
# Question 4
# What does T stand for in REST?
#
# 1 / 1 point
#
# Transform
#
#
# Tensor
#
#
# Transfer
#
#
# Transport
#
# Correct
# Correct! The T in REST stands for transfer.
#
# 5.
# Question 5
# Which of the following data sets is considered open data?
#
# 1 / 1 point
#
# Government data
#
#
# Commercially sensitive
#
#
# Customer data
#
#
# Pricing data
#
# Correct
# Correct! Government data covering the economy, society, healthcare, transportation, and environment are open data.
#
# 6.
# Question 6
# Which license  stipulates that the modified version of the data should be published under the same license terms as the original data ?
#
# 0 / 1 point
#
# CDLA-License
#
#
# CDLA-Dataset
#
#
# CDLA-Sharing
#
#
# CDLA-Permissive
#
# Incorrect
# Incorrect. Review the Data Sets - Powering Data Science video.
#
# 7.
# Question 7
# Which tab on the IBM developer web page enables you to open the Data Asset eXchange page?
#
# 0 / 1 point
#
# Community
#
#
# Products & Services
#
#
# Open Source at IBM
#
#
# Topics
#
# Incorrect
# Incorrect. Review the Sharing Enterprise Data - Data Asset eXchange video.
#
# 8.
# Question 8
# Which tab in the Data Asset eXchange project page enables you to view all the Jupyter Notebooks?
#
# 0 / 1 point
#
# Manage
#
#
# Assets
#
#
# Overview
#
#
# Jobs
#
# Incorrect
# Incorrect. Review the Sharing Enterprise Data - Data Asset eXchange video.
#
# 9.
# Question 9
# Which machine learning model is used to solve regression and classification problems?
#
# 0 / 1 point
#
# Model training
#
#
# Supervised Learning
#
#
# Reinforcement Learning
#
#
# Unsupervised Learning
#
# Incorrect
# Incorrect. Review the Machine Learning Models - Learning from Models to Make Predictions video.
#
# 10.
# Question 10
# On the MAX object detector page, which online tool is used by developers to edit front-end languages?
#
# 1 / 1 point
#
# Serverless app
#
#
# Node-Red Flow
#
#
# Extract Prediction
#
#
# CodePen
#
# Correct
# Correct! CodePen is an online tool used by developers to edit front-end languages like HTML, JavaScript, and CSS.

# %% [markdown]
# ![image.png](attachment:image.png)
